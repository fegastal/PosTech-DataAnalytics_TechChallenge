# %% [markdown]
# <a href="https://colab.research.google.com/github/fegastal/PosTech-DataAnalytics_TechChallenge/blob/main/Tech_Challenge_v1_Fernanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exportando banco de dados**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="whitegrid", palette="pastel")

# %%
# 3 países que mais exportaram em 2007
# 3 países que mais exportaram em 2015
# 3 países que mais exportaram em 2021

# %% [markdown]
# **1º PARTE - 3 PAÍSES QUE MAIS EXPORTARAM EM 2007**

# %%
dados_2007= pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2007&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

# %%
dados_2007 = dados_2007[5]
dados_2007.to_csv('dados_2007.csv', index=False)

# %%
dados_2007["Quantidade (Kg)"] = dados_2007["Quantidade (Kg)"].str.replace('.','').replace('-', '0')
dados_2007["Valor (US$)"] = dados_2007["Valor (US$)"].str.replace('.','').replace('-', '0')
# Out:
# <ipython-input-255-20a6e1b49af3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_2007["Quantidade (Kg)"] = dados_2007["Quantidade (Kg)"].str.replace('.','').replace('-', '0')
# <ipython-input-255-20a6e1b49af3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_2007["Valor (US$)"] = dados_2007["Valor (US$)"].str.replace('.','').replace('-', '0')

# %%
dados_2007["Quantidade (Kg)"] = pd.to_numeric(dados_2007["Quantidade (Kg)"], downcast="integer")
dados_2007["Valor (US$)"] = pd.to_numeric(dados_2007["Valor (US$)"], downcast="float")

# %%
dados_2007 = dados_2007.groupby(['Países']).agg({'Quantidade (Kg)':'sum','Valor (US$)':'sum' })

# %%
dados_2007 = dados_2007.reset_index()

# %%
dados_2007 = dados_2007.rename(columns={'Países':"País destino"})

# %%
dados_2007 = dados_2007.sort_values(by='Quantidade (Kg)', ascending=False)

# %%
dados_2007 = dados_2007.iloc[1:]

# %%
dados_2007
# Out:
#                País destino  Quantidade (Kg)  Valor (US$)
# 90                 Paraguai          1285459     801519.0
# 45           Estados Unidos           479269     810038.0
# 71                    Japão           357943     316867.0
# 99                   Rússia           266400     173160.0
# 91            Países Baixos           181046     364751.0
# ..                      ...              ...          ...
# 47                Filipinas                0          0.0
# 44                  Espanha                0          0.0
# 43      Eslovaca, Republica                0          0.0
# 41   Emirados Arabes Unidos                0          0.0
# 124                 Áustria                0          0.0
#
# [124 rows x 3 columns]

# %%
top_paises_2007 = dados_2007.head(3)

# %%
#plt.figure(figsize=(12, 6))
#sns.barplot(data=top_paises_2007, x='País destino', y='Quantidade (Kg)')
#plt.title('Exportação de Vinhos do Brasil por País em 2007 (Top 3)')
#plt.xlabel('País', fontweight='bold')
#plt.ylabel('Quantidade (Kg)', fontweight='bold')
#plt.show()

# %%
#plt.figure(figsize=(12, 6))
#sns.barplot(data=top_paises_2007, x='País destino', y='Quantidade (Kg)')
#plt.title('Exportação de Vinhos do Brasil por País em 2007 (Top 3)')
#plt.yscale('log')
#plt.xlabel('País', fontweight='bold')
#plt.ylabel('Quantidade (Kg)', fontweight='bold')
#plt.show()

# %%
top_paises_2007['Quantidade (Toneladas)'] = top_paises_2007['Quantidade (Kg)'] / 1000
# Out:
# <ipython-input-304-a0c65da5993e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_paises_2007['Quantidade (Toneladas)'] = top_paises_2007['Quantidade (Kg)'] / 1000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top_paises_2007, x='País destino', y='Quantidade (Toneladas)')
plt.title('Exportação de Vinhos do Brasil por País em 2021 (Top 3)')
plt.xlabel('País', fontweight='bold')
plt.ylabel('Quantidade (Toneladas)', fontweight='bold')
plt.gca().set_yticklabels(['{:.0f}t'.format(x) for x in plt.gca().get_yticks()])
# Out:
# <ipython-input-305-fa6d305b3f2d>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}t'.format(x) for x in plt.gca().get_yticks()])
# [Text(0, 0.0, '0t'),
#  Text(0, 200.0, '200t'),
#  Text(0, 400.0, '400t'),
#  Text(0, 600.0, '600t'),
#  Text(0, 800.0, '800t'),
#  Text(0, 1000.0, '1000t'),
#  Text(0, 1200.0, '1200t'),
#  Text(0, 1400.0, '1400t')]

# %% [markdown]
# **2º PARTE - 3 PAÍSES QUE MAIS EXPORTARAM EM 2015**

# %%
dados_2015 = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2015&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

# %%
dados_2015 = dados_2015[5]
dados_2015.to_csv('dados_2015.csv', index=False)

# %%
dados_2015["Quantidade (Kg)"] = dados_2015["Quantidade (Kg)"].str.replace('.','').replace('-', '0')
dados_2015["Valor (US$)"] = dados_2015["Valor (US$)"].str.replace('.','').replace('-', '0')
# Out:
# <ipython-input-268-7286d96db98c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_2015["Quantidade (Kg)"] = dados_2015["Quantidade (Kg)"].str.replace('.','').replace('-', '0')
# <ipython-input-268-7286d96db98c>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_2015["Valor (US$)"] = dados_2015["Valor (US$)"].str.replace('.','').replace('-', '0')

# %%
dados_2015["Quantidade (Kg)"] = pd.to_numeric(dados_2015["Quantidade (Kg)"], downcast="integer")
dados_2015["Valor (US$)"] = pd.to_numeric(dados_2015["Valor (US$)"], downcast="float")

# %%
dados_2015 = dados_2015.groupby(['Países']).agg({'Quantidade (Kg)':'sum','Valor (US$)':'sum' })

# %%
dados_2015 = dados_2015.reset_index()

# %%
dados_2015 = dados_2015.rename(columns={'Países':"País destino"})

# %%
dados_2015 = dados_2015.sort_values(by='Quantidade (Kg)', ascending=False)

# %%
dados_2015 = dados_2015.iloc[1:]

# %%
dados_2015
# Out:
#             País destino  Quantidade (Kg)  Valor (US$)
# 90              Paraguai           495428     741370.0
# 45        Estados Unidos           195896     524109.0
# 36                  Cuba            97965     108864.0
# 97           Reino Unido            68382     308407.0
# 95              Portugal            47736      42586.0
# ..                   ...              ...          ...
# 44               Espanha                0          0.0
# 43   Eslovaca, Republica                0          0.0
# 42               Equador                0          0.0
# 40           El Salvador                0          0.0
# 124              Áustria                0          0.0
#
# [124 rows x 3 columns]

# %%
top_paises_2015 = dados_2015.head(3)

# %%
#plt.figure(figsize=(12, 6))
#sns.barplot(data=top_paises_2015, x='País destino', y='Quantidade (Kg)')
#plt.title('Exportação de Vinhos do Brasil por País em 2015 (Top 3)')
#plt.xlabel('País', fontweight='bold')
#plt.ylabel('Quantidade (Kg)', fontweight='bold')
#plt.show()

# %%
#plt.figure(figsize=(12, 6))
#sns.barplot(data=top_paises_2015, x='País destino', y='Quantidade (Kg)')
#plt.title('Exportação de Vinhos do Brasil por País em 2015 (Top 3)')
#plt.yscale('log')
#plt.xlabel('País', fontweight='bold')
#plt.ylabel('Quantidade (Kg)', fontweight='bold')
#plt.show()

# %%
top_paises_2015['Quantidade (Toneladas)'] = top_paises_2015['Quantidade (Kg)'] / 1000
# Out:
# <ipython-input-302-cdfd946380fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_paises_2015['Quantidade (Toneladas)'] = top_paises_2015['Quantidade (Kg)'] / 1000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top_paises_2015, x='País destino', y='Quantidade (Toneladas)')
plt.title('Exportação de Vinhos do Brasil por País em 2021 (Top 3)')
plt.xlabel('País', fontweight='bold')
plt.ylabel('Quantidade (Toneladas)', fontweight='bold')
plt.gca().set_yticklabels(['{:.0f}t'.format(x) for x in plt.gca().get_yticks()])
# Out:
# <ipython-input-303-a0fe937df716>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}t'.format(x) for x in plt.gca().get_yticks()])
# [Text(0, 0.0, '0t'),
#  Text(0, 100.0, '100t'),
#  Text(0, 200.0, '200t'),
#  Text(0, 300.0, '300t'),
#  Text(0, 400.0, '400t'),
#  Text(0, 500.0, '500t'),
#  Text(0, 600.0, '600t')]

# %% [markdown]
# **3º PARTE - PAÍSES QUE MAIS EXPORTARAM EM 2021**

# %%
dados_2021 = pd.read_html('http://vitibrasil.cnpuv.embrapa.br/index.php?ano=2021&opcao=opt_06&subopcao=subopt_01',encoding='UTF-8' )

# %%
dados_2021 = dados_2021[5]
dados_2021.to_csv('dados_2021.csv', index=False)

# %%
dados_2021["Quantidade (Kg)"] = dados_2021["Quantidade (Kg)"].str.replace('.','').replace('-', '0')
dados_2021["Valor (US$)"] = dados_2021["Valor (US$)"].str.replace('.','').replace('-', '0')
# Out:
# <ipython-input-281-0c8ad18de1aa>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_2021["Quantidade (Kg)"] = dados_2021["Quantidade (Kg)"].str.replace('.','').replace('-', '0')
# <ipython-input-281-0c8ad18de1aa>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_2021["Valor (US$)"] = dados_2021["Valor (US$)"].str.replace('.','').replace('-', '0')

# %%
dados_2021["Quantidade (Kg)"] = pd.to_numeric(dados_2021["Quantidade (Kg)"], downcast="integer")
dados_2021["Valor (US$)"] = pd.to_numeric(dados_2021["Valor (US$)"], downcast="float")

# %%
dados_2021 = dados_2021.groupby(['Países']).agg({'Quantidade (Kg)':'sum','Valor (US$)':'sum' })

# %%
dados_2021 = dados_2021.reset_index()

# %%
dados_2021 = dados_2021.rename(columns={'Países':"País destino"})

# %%
dados_2021 = dados_2021.sort_values(by='Quantidade (Kg)', ascending=False)

# %%
dados_2021 = dados_2021.iloc[1:]

# %%
dados_2021
# Out:
#         País destino  Quantidade (Kg)  Valor (US$)
# 90          Paraguai          6522527    7192362.0
# 58             Haiti           670379     831181.0
# 99            Rússia           181931     312926.0
# 119          Uruguai           136774     149842.0
# 45    Estados Unidos           111085     203554.0
# ..               ...              ...          ...
# 35           Croácia                0          0.0
# 34   Costa do Marfim                0          0.0
# 94        Porto Rico                0          0.0
# 33        Costa Rica                0          0.0
# 124          Áustria                0          0.0
#
# [124 rows x 3 columns]

# %%
top_paises_2021 = dados_2021.head(3)

# %%
#plt.figure(figsize=(12, 6))
#sns.barplot(data=top_paises_2021, x='País destino', y='Quantidade (Kg)')
#plt.title('Exportação de Vinhos do Brasil por País em 2021 (Top 3)')
#plt.xlabel('País', fontweight='bold')
#plt.ylabel('Quantidade (Kg)', fontweight='bold')
#plt.show()

# %%
#plt.figure(figsize=(12, 6))
#sns.barplot(data=top_paises_2021, x='País destino', y='Quantidade (Kg)')
#plt.title('Exportação de Vinhos do Brasil por País em 2021 (Top 3)')
#plt.yscale('log')  # Definir escala logarítmica no eixo y
#plt.xlabel('País', fontweight='bold')
#plt.ylabel('Quantidade (Kg)', fontweight='bold')
#plt.show()

# %%
top_paises_2021['Quantidade (Toneladas)'] = top_paises_2021['Quantidade (Kg)'] / 1000
# Out:
# <ipython-input-298-c03e7ef0410e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_paises_2021['Quantidade (Toneladas)'] = top_paises_2021['Quantidade (Kg)'] / 1000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top_paises_2021, x='País destino', y='Quantidade (Toneladas)')
plt.title('Exportação de Vinhos do Brasil por País em 2021 (Top 3)')
plt.xlabel('País', fontweight='bold')
plt.ylabel('Quantidade (Toneladas)', fontweight='bold')
plt.gca().set_yticklabels(['{:.0f}t'.format(x) for x in plt.gca().get_yticks()])
# Out:
# <ipython-input-301-9ba64574db90>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}t'.format(x) for x in plt.gca().get_yticks()])
# [Text(0, 0.0, '0t'),
#  Text(0, 1000.0, '1000t'),
#  Text(0, 2000.0, '2000t'),
#  Text(0, 3000.0, '3000t'),
#  Text(0, 4000.0, '4000t'),
#  Text(0, 5000.0, '5000t'),
#  Text(0, 6000.0, '6000t'),
#  Text(0, 7000.0, '7000t')]

# %% [markdown]
# **4º PARTE - ANÁLISE DOS DADOS GERADOS**

# %% [markdown]
# Ao analisar os dados de exportação de vinho nos anos de 2007, 2015 e 2021, observa-se algumas mudanças significativas no cenário da exportação de vinho no mundo. Vamos explorar essas mudanças em termos de dados e possíveis contextos socioeconômicos:
#
# 1 | Mudanças nos maiores exportadores: Ao longo dos três anos, houve variações nos países que ocuparam as posições de maiores exportadores de vinho. O Paraguai foi o maior exportador em todos os anos, enquanto os Estados Unidos estiveram entre os três maiores exportadores em 2007 e 2015. Cuba e o Haiti surgiram como grandes exportadores em 2015 e 2021, respectivamente, indicando possíveis mudanças na dinâmica do mercado.
#
# 2 | Aumento da quantidade exportada: Em termos de quantidade exportada, observa-se um aumento considerável de 2007 para 2021, com o Paraguai liderando em todos os anos. Em 2021, o Paraguai registrou uma exportação significativamente maior em comparação aos outros países, indicando um possível crescimento do setor vitivinícola paraguaio ao longo dos anos.
#
# 3 | Emergência de novos exportadores: A inclusão de Cuba em 2015 e do Haiti em 2021 como grandes exportadores de vinho pode ser atribuída a diversos fatores. Esses países podem ter investido na produção de vinho, aumentado sua capacidade produtiva ou melhorado suas práticas de exportação. Mudanças nas políticas comerciais e acesso a novos mercados também podem ter desempenhado um papel importante.
#
# 4 | Possíveis fatores socioeconômicos: Várias razões socioeconômicas podem ter influenciado essas mudanças no cenário da exportação de vinho. Alguns fatores que podem ser considerados incluem políticas governamentais favoráveis ao setor vitivinícola, investimentos em infraestrutura e tecnologia, melhorias na qualidade dos vinhos produzidos, abertura de novos mercados internacionais, mudanças nas preferências dos consumidores e acordos comerciais.
#
# 5 | Contexto regional e global: É importante considerar o contexto regional e global do setor vitivinícola ao analisar as mudanças na exportação de vinho. As tendências globais, como o crescimento da demanda por vinhos em mercados emergentes ou mudanças nos padrões de consumo, podem ter impacto nos países exportadores. Além disso, fatores como a concorrência de outros países produtores de vinho, flutuações cambiais e eventos globais também podem desempenhar um papel importante.
#
# É necessário realizar uma análise mais aprofundada e considerar dados adicionais, como informações sobre a produção interna de vinho, consumo interno, acordos comerciais específicos e políticas governamentais em cada país, a fim de compreender completamente o contexto socioeconômico das mudanças na exportação de vinho ao longo desses três anos.
